# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed-celeba-small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size), transforms.ToTensor()])
    dataset = datasets.ImageFolder(data_dir, transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 24
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    
    min_rng, max_rng = feature_range
    x = x*(max_rng-min_rng) + min_rng
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(0.8353)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
  def conv(inputs, outputs, kernel_size=4, stride=2, padding=1, batch_norm=True):
    nn_layers = []
    layer = nn.Conv2d(inputs, outputs, kernel_size, stride, padding, bias=False)
    nn_layers.append(layer)
    if batch_norm:
        nn_layers.append(nn.BatchNorm2d(outputs))
    return nn.Sequential(*nn_layers)

def deconv(inputs, outputs, kernel_size=4, stride=2, padding=1, batch_norm=True):
    nn_layers = []
    layer = nn.ConvTranspose2d(inputs, outputs, kernel_size, stride, padding, bias=False)
    nn_layers.append(layer)
    if batch_norm:
        nn_layers.append(nn.BatchNorm2d(outputs))
    return nn.Sequential(*nn_layers)

class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        self.leaky_relu_slope = 0.2
        
        # 32x32 input
        self.conv1 = conv(3,conv_dim,4,batch_norm = False)
        # 16x16 output
        self.conv2 = conv(conv_dim,conv_dim*2,4)
        # 8x8 output
        self.conv3 = conv(conv_dim*2,conv_dim*4,4)
        # 2x2 output
        self.conv4 = conv(conv_dim*4,conv_dim*8,4)

        # Fully connected layer
        self.fc = nn.Linear(conv_dim*4*4*4,1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x),self.leaky_relu_slope)
        x = F.leaky_relu(self.conv2(x),self.leaky_relu_slope)
        x = F.leaky_relu(self.conv3(x),self.leaky_relu_slope)
        # Flatten
        x = x.view(-1,self.conv_dim*4*4*4)
        x = self.fc(x)
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        self.deconv1 = deconv(conv_dim*8,conv_dim*4,4)
        self.deconv2 = deconv(conv_dim*4,conv_dim*2,4)
        self.deconv3 = deconv(conv_dim*2,conv_dim)
        self.deconv4 = deconv(conv_dim,3,batch_norm = False)  
        
        self.fc = nn.Linear(z_size,conv_dim*32)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        
        # X View (batch_size, depth, width,height)
        x = x.view(-1,self.conv_dim*8,2,2) 
        
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        x = F.relu(self.deconv3(x))
        x = torch.tanh(self.deconv4(x))        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m,'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        
        m.weight.data.normal_(0.0,0.02)
    
        if hasattr(m,'bias') and m.bias is not None:
            m.bias.data.zero_()

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (fc): Linear(in_features=100, out_features=1024, bias=True)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size).cuda()
    criterion = nn.BCEWithLogitsLoss()   
    D_out = D_out.squeeze()
    loss = criterion(D_out,labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size).cuda()
    criterion = nn.BCEWithLogitsLoss()  
    D_out = D_out.squeeze()
    loss = criterion(D_out,labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

def fn(epoch):
    if epoch <20:
        print('Constant learning rate')
        return 1.0
    else:
        print('Reduced learning rate')
        return 1.0 - (epoch - 20) * 0.05

# Create optimizers for the discriminator D and generator G
optimizer_D = optim.Adam(D.parameters(),lr = .0002, betas = [0.5,0.999])
scheduler_D = lr_scheduler.LambdaLR(optimizer_D, fn)

optimizer_G = optim.Adam(G.parameters(),lr = .0002, betas = [0.5,0.999])
scheduler_G = lr_scheduler.LambdaLR(optimizer_G, fn)
# Out:
# Constant learning rate
# Constant learning rate

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D = D.cuda()
        D = nn.DataParallel(D)
        G = G.cuda()
        G = nn.DataParallel(G)       

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):
        
        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            optimizer_D.zero_grad()
            
            # 1. Train the discriminator on real and fake images
            if train_on_gpu:
                real_images = real_images.cuda()   
            D_real = D(real_images)
            d_real_out = real_loss(D_real)
            
            # Generate fake images
            z = np.random.uniform(-1,1,size = (batch_size,z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)    
            D_fake = D(fake_images)
            d_fake_out = fake_loss(D_fake)
            
            # Discriminator losses for fake images    
            d_loss = d_real_out + d_fake_out
#             d_loss.backward()
            d_loss.backward(retain_graph=True)
            optimizer_D.step() 

            # 2. Train the generator with an adversarial loss
            optimizer_G.zero_grad()
            z = np.random.uniform(-1,1,size = (batch_size,z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            
            # back prop
            g_loss.backward()
            optimizer_G.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item())) 
                print('G Learning Rate:', scheduler_G.get_lr())
                print('D Learning Rate:', scheduler_D.get_lr())
                                            
        scheduler_D.step()
        scheduler_G.step()
                     
        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 40

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   40] | d_loss: 1.2345 | g_loss: 1.1677
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# /home/mif/.local/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Epoch [    1/   40] | d_loss: 0.1366 | g_loss: 3.9016
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.1039 | g_loss: 4.8564
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.1522 | g_loss: 4.0809
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.4265 | g_loss: 1.7636
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.2840 | g_loss: 4.1551
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8321 | g_loss: 2.0676
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7516 | g_loss: 1.8652
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6062 | g_loss: 2.3200
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7362 | g_loss: 1.9979
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8008 | g_loss: 3.0400
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0746 | g_loss: 4.5488
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8282 | g_loss: 1.9458
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.5670 | g_loss: 2.4198
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7771 | g_loss: 3.0060
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8681 | g_loss: 1.6646
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9960 | g_loss: 3.3824
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8230 | g_loss: 3.4525
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6594 | g_loss: 2.4828
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.1043 | g_loss: 2.1891
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9914 | g_loss: 1.1147
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.5143 | g_loss: 0.7655
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8326 | g_loss: 1.3223
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6802 | g_loss: 2.6507
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8245 | g_loss: 3.1986
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.5928 | g_loss: 3.1497
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0437 | g_loss: 2.4929
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0483 | g_loss: 3.1272
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8276 | g_loss: 1.6423
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8875 | g_loss: 2.6932
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8001 | g_loss: 1.7127
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6265 | g_loss: 2.4276
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.5654 | g_loss: 2.4191
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8476 | g_loss: 1.9639
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6832 | g_loss: 2.1001
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7379 | g_loss: 1.9491
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7453 | g_loss: 1.7603
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9377 | g_loss: 1.5049
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7902 | g_loss: 1.8732
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0419 | g_loss: 1.2587
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9453 | g_loss: 1.4779
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9278 | g_loss: 2.0043
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9357 | g_loss: 2.2624
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9062 | g_loss: 1.4179
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.1755 | g_loss: 1.2021
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6985 | g_loss: 2.0464
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8761 | g_loss: 2.1589
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8292 | g_loss: 1.8931
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.2952 | g_loss: 1.5966
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.3135 | g_loss: 0.8475
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.1961 | g_loss: 1.3432
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6786 | g_loss: 2.2964
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7929 | g_loss: 2.3231
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.6133 | g_loss: 2.2264
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9170 | g_loss: 1.5633
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8950 | g_loss: 1.6931
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0291 | g_loss: 1.9259
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.7069 | g_loss: 1.9235
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9183 | g_loss: 1.5929
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.2268 | g_loss: 1.8130
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.2425 | g_loss: 1.0334
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8014 | g_loss: 1.7786
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0523 | g_loss: 2.7899
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8789 | g_loss: 1.7669
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9576 | g_loss: 1.8341
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0984 | g_loss: 1.0162
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8946 | g_loss: 1.4012
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.1923 | g_loss: 1.7805
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.1940 | g_loss: 1.0569
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.2931 | g_loss: 1.3130
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.8947 | g_loss: 1.5209
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.1848 | g_loss: 2.4634
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0140 | g_loss: 1.9647
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 0.9851 | g_loss: 1.5834
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    1/   40] | d_loss: 1.0216 | g_loss: 1.7022
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Constant learning rate
# Constant learning rate
# Epoch [    2/   40] | d_loss: 1.7232 | g_loss: 2.1327
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9451 | g_loss: 1.5586
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8972 | g_loss: 1.7132
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2091 | g_loss: 1.2300
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0274 | g_loss: 1.6354
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0120 | g_loss: 1.4306
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0162 | g_loss: 1.3621
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.1909 | g_loss: 2.0491
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.7418 | g_loss: 1.6508
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0506 | g_loss: 1.3951
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0498 | g_loss: 2.4531
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.5858 | g_loss: 1.8720
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0671 | g_loss: 1.2649
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0563 | g_loss: 1.4752
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9126 | g_loss: 1.9181
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2022 | g_loss: 1.1564
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9443 | g_loss: 1.7256
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8316 | g_loss: 1.5638
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9860 | g_loss: 1.9179
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.3276 | g_loss: 0.9655
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2669 | g_loss: 1.5046
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.1793 | g_loss: 1.4298
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8060 | g_loss: 1.7631
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2394 | g_loss: 1.7683
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8929 | g_loss: 1.5212
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2813 | g_loss: 1.0645
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0372 | g_loss: 1.3136
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0264 | g_loss: 1.3489
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9711 | g_loss: 2.2198
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.4106 | g_loss: 0.8350
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0078 | g_loss: 1.2566
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9900 | g_loss: 1.6818
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.1622 | g_loss: 1.3165
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.1066 | g_loss: 1.1310
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0159 | g_loss: 1.6446
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9391 | g_loss: 1.4648
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8852 | g_loss: 1.9118
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0575 | g_loss: 1.3557
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9750 | g_loss: 1.4053
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0176 | g_loss: 2.5208
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0005 | g_loss: 1.7300
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.7916 | g_loss: 1.8902
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.3015 | g_loss: 1.9547
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8408 | g_loss: 1.8154
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.6699 | g_loss: 2.3979
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8626 | g_loss: 1.5512
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.1442 | g_loss: 2.4486
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8338 | g_loss: 1.7756
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8838 | g_loss: 1.7439
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0617 | g_loss: 1.3449
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8789 | g_loss: 1.7959
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0760 | g_loss: 1.6984
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8248 | g_loss: 1.7329
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9414 | g_loss: 1.6045
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8827 | g_loss: 1.9231
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.7865 | g_loss: 1.6116
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0772 | g_loss: 2.0137
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9862 | g_loss: 0.9225
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0809 | g_loss: 1.6082
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9234 | g_loss: 1.3799
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9746 | g_loss: 1.4314
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8248 | g_loss: 2.0601
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9984 | g_loss: 1.4165
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.1035 | g_loss: 1.2277
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9237 | g_loss: 1.7578
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8245 | g_loss: 2.1570
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8027 | g_loss: 1.7797
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.9766 | g_loss: 1.8162
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.7582 | g_loss: 1.6531
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.6683 | g_loss: 2.0839
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2204 | g_loss: 1.2557
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.8215 | g_loss: 1.6373
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 0.6836 | g_loss: 2.0814
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.0399 | g_loss: 1.4525
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    2/   40] | d_loss: 1.2316 | g_loss: 1.4023
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Constant learning rate
# Constant learning rate
# Epoch [    3/   40] | d_loss: 1.0623 | g_loss: 1.5826
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9094 | g_loss: 1.8017
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.4110 | g_loss: 0.8602
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8085 | g_loss: 1.7982
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8184 | g_loss: 2.1119
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8986 | g_loss: 0.9498
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.1506 | g_loss: 1.1811
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7860 | g_loss: 1.5042
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0866 | g_loss: 1.5918
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.3416 | g_loss: 1.3083
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6520 | g_loss: 2.0475
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9267 | g_loss: 1.7309
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.1466 | g_loss: 0.9810
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7316 | g_loss: 1.8981
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.2008 | g_loss: 1.1339
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8620 | g_loss: 1.5154
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0104 | g_loss: 1.4433
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6625 | g_loss: 2.0198
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0018 | g_loss: 1.3428
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8691 | g_loss: 1.6363
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8903 | g_loss: 1.8002
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8931 | g_loss: 1.4004
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6811 | g_loss: 1.5158
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9173 | g_loss: 1.5959
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.2232 | g_loss: 2.2237
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6886 | g_loss: 1.8431
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.1261 | g_loss: 1.6032
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8978 | g_loss: 2.2361
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7631 | g_loss: 2.1482
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7515 | g_loss: 1.7575
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0978 | g_loss: 2.2850
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9857 | g_loss: 1.7234
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9651 | g_loss: 2.0277
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9499 | g_loss: 1.4102
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7151 | g_loss: 1.7496
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9747 | g_loss: 1.6915
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6572 | g_loss: 1.9990
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0060 | g_loss: 1.2998
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7084 | g_loss: 1.7555
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0544 | g_loss: 2.6899
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8182 | g_loss: 1.8348
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.2047 | g_loss: 1.7049
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.1493 | g_loss: 1.8266
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8929 | g_loss: 1.6259
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6904 | g_loss: 2.1695
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6956 | g_loss: 1.7065
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9056 | g_loss: 1.9620
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7534 | g_loss: 1.9261
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0400 | g_loss: 1.8473
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0647 | g_loss: 1.1475
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0888 | g_loss: 2.0159
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.1084 | g_loss: 1.3033
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9565 | g_loss: 2.1790
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0430 | g_loss: 1.6679
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.5741 | g_loss: 1.7202
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7761 | g_loss: 1.2778
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7697 | g_loss: 2.0479
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7828 | g_loss: 2.2637
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.0029 | g_loss: 2.8295
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9738 | g_loss: 1.4950
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9334 | g_loss: 1.9347
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.3039 | g_loss: 1.3358
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7950 | g_loss: 1.6880
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.5487 | g_loss: 2.4708
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9032 | g_loss: 2.2610
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.7724 | g_loss: 1.9862
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6806 | g_loss: 2.3887
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.1842 | g_loss: 1.7236
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.3055 | g_loss: 1.6863
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.3717 | g_loss: 1.4113
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8147 | g_loss: 2.4172
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.8054 | g_loss: 1.8877
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.9008 | g_loss: 2.5945
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 0.6571 | g_loss: 1.6853
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    3/   40] | d_loss: 1.4396 | g_loss: 0.5957
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Constant learning rate
# Constant learning rate
# Epoch [    4/   40] | d_loss: 1.6060 | g_loss: 1.8063
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7150 | g_loss: 1.9235
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1193 | g_loss: 2.3269
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6917 | g_loss: 2.0251
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6626 | g_loss: 2.2442
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9231 | g_loss: 1.7568
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1301 | g_loss: 1.2737
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8860 | g_loss: 2.0139
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.7961 | g_loss: 0.5719
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.0278 | g_loss: 2.2441
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1934 | g_loss: 2.6467
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8080 | g_loss: 2.1700
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7936 | g_loss: 2.2261
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.5368 | g_loss: 1.7256
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1866 | g_loss: 1.0112
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9473 | g_loss: 1.3829
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1765 | g_loss: 1.8516
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9406 | g_loss: 1.5936
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8029 | g_loss: 1.2277
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7356 | g_loss: 2.3258
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8074 | g_loss: 1.4930
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9344 | g_loss: 1.4866
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.0473 | g_loss: 1.2046
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9589 | g_loss: 1.4974
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8004 | g_loss: 1.9388
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6013 | g_loss: 2.6384
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6448 | g_loss: 1.8221
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8954 | g_loss: 1.7923
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9102 | g_loss: 1.4267
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1082 | g_loss: 1.6765
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9352 | g_loss: 1.6959
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8106 | g_loss: 1.6582
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.2149 | g_loss: 2.2451
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8777 | g_loss: 1.5436
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8878 | g_loss: 1.5715
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.4931 | g_loss: 1.2887
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.3172 | g_loss: 1.8066
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9805 | g_loss: 1.4967
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.5380 | g_loss: 2.7953
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7903 | g_loss: 1.9603
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.4918 | g_loss: 3.0164
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7561 | g_loss: 1.6821
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6608 | g_loss: 1.7417
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8975 | g_loss: 1.7666
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1645 | g_loss: 1.7084
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9614 | g_loss: 1.2316
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7887 | g_loss: 2.0800
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6948 | g_loss: 1.5981
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8675 | g_loss: 2.1924
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8510 | g_loss: 2.6788
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.2356 | g_loss: 1.8144
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6809 | g_loss: 2.5886
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8128 | g_loss: 1.5817
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6880 | g_loss: 1.7194
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6018 | g_loss: 2.4607
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.4381 | g_loss: 2.3831
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.0859 | g_loss: 1.4675
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7645 | g_loss: 1.6366
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.5218 | g_loss: 1.7401
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1579 | g_loss: 2.4434
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.2407 | g_loss: 1.5036
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7076 | g_loss: 1.7868
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.5023 | g_loss: 2.0315
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.3261 | g_loss: 1.0731
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.9772 | g_loss: 1.5411
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7862 | g_loss: 1.8750
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.5116 | g_loss: 0.9805
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8214 | g_loss: 1.4744
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.1061 | g_loss: 1.7682
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6261 | g_loss: 2.4103
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.7165 | g_loss: 1.3743
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 1.0938 | g_loss: 0.9278
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6488 | g_loss: 1.8888
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.6844 | g_loss: 2.5763
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    4/   40] | d_loss: 0.8811 | g_loss: 1.5992
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Constant learning rate
# Constant learning rate
# Epoch [    5/   40] | d_loss: 0.6899 | g_loss: 2.5200
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 1.0167 | g_loss: 1.7853
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.6589 | g_loss: 1.7515
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.7707 | g_loss: 1.4460
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.9045 | g_loss: 1.5893
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.6073 | g_loss: 2.2800
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.9788 | g_loss: 1.1082
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 1.1117 | g_loss: 1.7463
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.7145 | g_loss: 2.0038
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.8525 | g_loss: 1.2590
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 1.1625 | g_loss: 2.0034
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 0.7201 | g_loss: 1.3671
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [    5/   40] | d_loss: 1.4685 | g_loss: 1.2463
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# ...
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5169 | g_loss: 2.7234
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.7098 | g_loss: 2.1339
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3231 | g_loss: 3.6177
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.7444 | g_loss: 3.0932
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5533 | g_loss: 1.8872
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3180 | g_loss: 3.0916
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6570 | g_loss: 2.6020
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.7686 | g_loss: 2.1219
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3922 | g_loss: 2.2816
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4470 | g_loss: 3.5116
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4695 | g_loss: 3.5443
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6000 | g_loss: 3.1223
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6099 | g_loss: 3.3325
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3973 | g_loss: 3.6011
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4626 | g_loss: 2.3284
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3967 | g_loss: 2.7986
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.7702 | g_loss: 2.7577
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4057 | g_loss: 2.8868
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3464 | g_loss: 4.0698
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3884 | g_loss: 2.0608
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5488 | g_loss: 3.1825
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.7785 | g_loss: 3.2329
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6157 | g_loss: 2.8271
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6844 | g_loss: 2.1120
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4772 | g_loss: 2.5723
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4361 | g_loss: 3.4540
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.8020 | g_loss: 1.2428
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6800 | g_loss: 1.9920
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4915 | g_loss: 2.2214
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5756 | g_loss: 3.4724
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5482 | g_loss: 4.1814
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.8989 | g_loss: 1.9181
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.7521 | g_loss: 3.0789
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3016 | g_loss: 3.2537
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.8977 | g_loss: 3.3596
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.1744 | g_loss: 3.5702
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4448 | g_loss: 2.5438
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4707 | g_loss: 2.6390
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4314 | g_loss: 2.5982
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.9715 | g_loss: 1.7082
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6034 | g_loss: 2.8812
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 1.1317 | g_loss: 2.7576
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 1.4489 | g_loss: 2.3454
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.2714 | g_loss: 2.8006
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4584 | g_loss: 3.1471
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3699 | g_loss: 3.0928
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3592 | g_loss: 2.6410
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4760 | g_loss: 4.3106
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5532 | g_loss: 2.3948
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5184 | g_loss: 3.2646
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.6334 | g_loss: 3.7682
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.2512 | g_loss: 3.3797
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5754 | g_loss: 1.8360
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4155 | g_loss: 3.2145
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.3190 | g_loss: 3.5623
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.2671 | g_loss: 3.3015
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.4180 | g_loss: 2.7883
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   17/   40] | d_loss: 0.5409 | g_loss: 2.5323
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Constant learning rate
# Constant learning rate
# Epoch [   18/   40] | d_loss: 0.4355 | g_loss: 2.8499
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5105 | g_loss: 3.0589
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3135 | g_loss: 3.9580
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4072 | g_loss: 3.7262
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3051 | g_loss: 3.8643
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5734 | g_loss: 2.9544
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.7054 | g_loss: 2.6590
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3294 | g_loss: 3.6258
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4800 | g_loss: 2.6910
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3789 | g_loss: 3.6817
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5460 | g_loss: 3.1267
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5387 | g_loss: 2.7757
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4824 | g_loss: 2.7560
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4201 | g_loss: 3.5043
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6811 | g_loss: 1.9319
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6745 | g_loss: 2.6153
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6302 | g_loss: 2.5156
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6371 | g_loss: 2.9498
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4775 | g_loss: 3.4990
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.7577 | g_loss: 1.7197
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5635 | g_loss: 3.2281
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 1.0799 | g_loss: 2.5110
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6350 | g_loss: 3.5729
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6302 | g_loss: 2.7047
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4196 | g_loss: 4.1058
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4222 | g_loss: 2.5235
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.2563 | g_loss: 3.1748
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4493 | g_loss: 3.2975
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4462 | g_loss: 3.2203
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3808 | g_loss: 3.4943
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6490 | g_loss: 2.3088
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6185 | g_loss: 1.6677
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4128 | g_loss: 2.7284
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4697 | g_loss: 2.7912
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3861 | g_loss: 3.0652
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.8812 | g_loss: 3.9274
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6249 | g_loss: 2.0778
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.6639 | g_loss: 3.6749
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.4180 | g_loss: 3.4515
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3947 | g_loss: 2.7851
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5744 | g_loss: 1.6430
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5429 | g_loss: 2.9864
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 1.0490 | g_loss: 1.3913
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.5428 | g_loss: 3.9314
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.3578 | g_loss: 3.4679
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]
# Epoch [   18/   40] | d_loss: 0.7449 | g_loss: 0.8029
# Constant learning rate
# G Learning Rate: [0.0002]
# Constant learning rate
# D Learning Rate: [0.0002]

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
